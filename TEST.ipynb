# %%
import pandas as pd
import joblib
import json

# %%
def load_model(model_file):
    """

    :param model_file:
    :return:
    """
    model = joblib.load(model_file)
    return model


def get_prediction_proba(model, query):
    """

    :param model:
    :param query:
    :return:
    """
    probability = model.predict_proba(query)
    return probability

# %%
model = load_model("models/HistBoost.joblib")
# Out:
# C:\Users\oumei\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:288: UserWarning: Trying to unpickle estimator _BinMapper from version 1.1.3 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\oumei\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:288: UserWarning: Trying to unpickle estimator HistGradientBoostingClassifier from version 1.1.3 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
proba = get_prediction_proba(model, client_df)

# %%
proba[:, 1]
# Out:
# array([0.05860599])

# %%
data = pd.read_csv(r"C:\Users\oumei\Documents\OC_projets\P7\P7_Data_Science_OpenClassrooms\dataset\cleaned\data_test_preprocessed_vf.csv")

# %%
client_id = 100001

# %%
client_df = data[data["SK_ID_CURR"] == client_id]
client_df
# Out:
#    SK_ID_CURR  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      100001            0             0                0             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0          135000.0    568800.0      20560.5         450000.0
#
#    REGION_POPULATION_RELATIVE  ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 0                     0.01885  ...                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 0                                         NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MIN  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# ...

# %%
client_string = client_df.to_json(orient="records")
client_string
# Out:
# '[{"SK_ID_CURR":100001,"CODE_GENDER":0,"FLAG_OWN_CAR":0,"FLAG_OWN_REALTY":0,"CNT_CHILDREN":0,"AMT_INCOME_TOTAL":135000.0,"AMT_CREDIT":568800.0,"AMT_ANNUITY":20560.5,"AMT_GOODS_PRICE":450000.0,"REGION_POPULATION_RELATIVE":0.01885,"DAYS_BIRTH":-19241,"DAYS_EMPLOYED":-2329.0,"DAYS_REGISTRATION":-5170.0,"DAYS_ID_PUBLISH":-812,"OWN_CAR_AGE":null,"FLAG_MOBIL":1,"FLAG_EMP_PHONE":1,"FLAG_WORK_PHONE":0,"FLAG_CONT_MOBILE":1,"FLAG_PHONE":0,"FLAG_EMAIL":1,"CNT_FAM_MEMBERS":2.0,"REGION_RATING_CLIENT":2,"REGION_RATING_CLIENT_W_CITY":2,"HOUR_APPR_PROCESS_START":18,"REG_REGION_NOT_LIVE_REGION":0,"REG_REGION_NOT_WORK_REGION":0,"LIVE_REGION_NOT_WORK_REGION":0,"REG_CITY_NOT_LIVE_CITY":0,"REG_CITY_NOT_WORK_CITY":0,"LIVE_CITY_NOT_WORK_CITY":0,"EXT_SOURCE_1":0.7526144906,"EXT_SOURCE_2":0.7896543511,"EXT_SOURCE_3":0.1595195405,"APARTMENTS_AVG":0.066,"BASEMENTAREA_AVG":0.059,"YEARS_BEGINEXPLUATATION_AVG":0.9732,"YEARS_BUILD_AVG":null,"COMMONAREA_AVG":null,"ELEVATORS_AVG":null,"ENTRANCES_AVG":0.1379,"FLOORSM
# ...

# %%
client_json = json.loads(client_string)[0]
client_json
# Out:
# {'SK_ID_CURR': 100001,
#  'CODE_GENDER': 0,
#  'FLAG_OWN_CAR': 0,
#  'FLAG_OWN_REALTY': 0,
#  'CNT_CHILDREN': 0,
#  'AMT_INCOME_TOTAL': 135000.0,
#  'AMT_CREDIT': 568800.0,
#  'AMT_ANNUITY': 20560.5,
#  'AMT_GOODS_PRICE': 450000.0,
#  'REGION_POPULATION_RELATIVE': 0.01885,
#  'DAYS_BIRTH': -19241,
#  'DAYS_EMPLOYED': -2329.0,
#  'DAYS_REGISTRATION': -5170.0,
#  'DAYS_ID_PUBLISH': -812,
#  'OWN_CAR_AGE': None,
#  'FLAG_MOBIL': 1,
#  'FLAG_EMP_PHONE': 1,
#  'FLAG_WORK_PHONE': 0,
#  'FLAG_CONT_MOBILE': 1,
#  'FLAG_PHONE': 0,
#  'FLAG_EMAIL': 1,
#  'CNT_FAM_MEMBERS': 2.0,
#  'REGION_RATING_CLIENT': 2,
#  'REGION_RATING_CLIENT_W_CITY': 2,
#  'HOUR_APPR_PROCESS_START': 18,
#  'REG_REGION_NOT_LIVE_REGION': 0,
#  'REG_REGION_NOT_WORK_REGION': 0,
#  'LIVE_REGION_NOT_WORK_REGION': 0,
#  'REG_CITY_NOT_LIVE_CITY': 0,
#  'REG_CITY_NOT_WORK_CITY': 0,
#  'LIVE_CITY_NOT_WORK_CITY': 0,
#  'EXT_SOURCE_1': 0.7526144906,
#  'EXT_SOURCE_2': 0.7896543511,
#  'EXT_SOURCE_3': 0.1595195405,
# ...

# %%
client_df
# Out:
#    SK_ID_CURR  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      100001            0             0                0             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0          135000.0    568800.0      20560.5         450000.0
#
#    REGION_POPULATION_RELATIVE  ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 0                     0.01885  ...                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 0                                         NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MIN  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# ...

# %%
client_string
# Out:
# '[{"SK_ID_CURR":100001,"CODE_GENDER":0,"FLAG_OWN_CAR":0,"FLAG_OWN_REALTY":0,"CNT_CHILDREN":0,"AMT_INCOME_TOTAL":135000.0,"AMT_CREDIT":568800.0,"AMT_ANNUITY":20560.5,"AMT_GOODS_PRICE":450000.0,"REGION_POPULATION_RELATIVE":0.01885,"DAYS_BIRTH":-19241,"DAYS_EMPLOYED":-2329.0,"DAYS_REGISTRATION":-5170.0,"DAYS_ID_PUBLISH":-812,"OWN_CAR_AGE":null,"FLAG_MOBIL":1,"FLAG_EMP_PHONE":1,"FLAG_WORK_PHONE":0,"FLAG_CONT_MOBILE":1,"FLAG_PHONE":0,"FLAG_EMAIL":1,"CNT_FAM_MEMBERS":2.0,"REGION_RATING_CLIENT":2,"REGION_RATING_CLIENT_W_CITY":2,"HOUR_APPR_PROCESS_START":18,"REG_REGION_NOT_LIVE_REGION":0,"REG_REGION_NOT_WORK_REGION":0,"LIVE_REGION_NOT_WORK_REGION":0,"REG_CITY_NOT_LIVE_CITY":0,"REG_CITY_NOT_WORK_CITY":0,"LIVE_CITY_NOT_WORK_CITY":0,"EXT_SOURCE_1":0.7526144906,"EXT_SOURCE_2":0.7896543511,"EXT_SOURCE_3":0.1595195405,"APARTMENTS_AVG":0.066,"BASEMENTAREA_AVG":0.059,"YEARS_BEGINEXPLUATATION_AVG":0.9732,"YEARS_BUILD_AVG":null,"COMMONAREA_AVG":null,"ELEVATORS_AVG":null,"ENTRANCES_AVG":0.1379,"FLOORSM
# ...

# %%
df_one_client = pd.Series(client_json).to_frame().transpose()
df_one_client
# Out:
#    SK_ID_CURR  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0    100001.0          0.0           0.0              0.0           0.0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0          135000.0    568800.0      20560.5         450000.0
#
#    REGION_POPULATION_RELATIVE  ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 0                     0.01885  ...                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 0                                         NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MIN  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# ...

# %%
client = pd.DataFrame.from_dict(client_json, orient="index").transpose()
client
# Out:
#    SK_ID_CURR  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0    100001.0          0.0           0.0              0.0           0.0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0          135000.0    568800.0      20560.5         450000.0
#
#    REGION_POPULATION_RELATIVE  ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 0                     0.01885  ...                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 0                                         NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 0                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MIN  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# ...

# %%
df_description = pd.read_csv(
    r"C:\Users\oumei\Documents\OC_projets\P7\P7_Data_Science_OpenClassrooms\dataset\source\HomeCredit_columns_description.csv",
    encoding="ISO-8859-1")

# %%
df_description
# Out:
#      Unnamed: 0                         Table                    Row  \
# 0             1  application_{train|test}.csv             SK_ID_CURR
# 1             2  application_{train|test}.csv                 TARGET
# 2             5  application_{train|test}.csv     NAME_CONTRACT_TYPE
# 3             6  application_{train|test}.csv            CODE_GENDER
# 4             7  application_{train|test}.csv           FLAG_OWN_CAR
# ..          ...                           ...                    ...
# 214         217     installments_payments.csv  NUM_INSTALMENT_NUMBER
# 215         218     installments_payments.csv        DAYS_INSTALMENT
# 216         219     installments_payments.csv     DAYS_ENTRY_PAYMENT
# 217         220     installments_payments.csv         AMT_INSTALMENT
# 218         221     installments_payments.csv            AMT_PAYMENT
#
#                                            Description  \
# 0                             ID of loan in our sample
# ...

# %%
json_shap = [
    {
        "SHAP value": 0.7284135961,
        "feature": "EXT_SOURCE_3"
    },
    {
        "SHAP value": 0.1467115956,
        "feature": "CODE_GENDER"
    },
    {
        "SHAP value": 0.1255849492,
        "feature": "ACTIVE_DAYS_CREDIT_MAX"
    },
    {
        "SHAP value": 0.0888431876,
        "feature": "INSTAL_DPD_MEAN"
    },
    {
        "SHAP value": 0.0828803212,
        "feature": "OWN_CAR_AGE"
    },
    {
        "SHAP value": 0.0818665965,
        "feature": "AMT_GOODS_PRICE"
    },
    {
        "SHAP value": 0.0791102165,
        "feature": "INSTAL_AMT_PAYMENT_SUM"
    },
    {
        "SHAP value": 0.0665215446,
        "feature": "POS_SK_DPD_DEF_MEAN"
    },
    {
        "SHAP value": 0.0482450318,
        "feature": "ACTIVE_DAYS_CREDIT_ENDDATE_MAX"
    },
    {
        "SHAP value": 0.0314722216,
        "feature": "ACTIVE_DAYS_CREDIT_ENDDATE_MEAN"
    },
    {
        "SHAP value": 0.0291357631,
        "feature": "ACTIVE_DAYS_CREDIT_ENDDATE_MIN"
    },
    {
        "SHAP value": 0.0277033456,
        "feature": "PREV_NAME_YIELD_GROUP_high_MEAN"
    },
    {
        "SHAP value": 0.0271566152,
        "feature": "REGION_POPULATION_RELATIVE"
    },
    {
        "SHAP value": 0.0262340654,
        "feature": "APPROVED_AMT_DOWN_PAYMENT_MAX"
    },
    {
        "SHAP value": 0.0259573544,
        "feature": "APPROVED_AMT_ANNUITY_MEAN"
    },
    {
        "SHAP value": 0.0258244999,
        "feature": "AMT_CREDIT"
    },
    {
        "SHAP value": 0.0242486219,
        "feature": "DAYS_ID_PUBLISH"
    },
    {
        "SHAP value": 0.0222171036,
        "feature": "POS_MONTHS_BALANCE_MAX"
    },
    {
        "SHAP value": 0.0220822908,
        "feature": "INSTAL_DAYS_ENTRY_PAYMENT_MAX"
    },
    {
        "SHAP value": 0.0214548425,
        "feature": "INSTAL_DBD_SUM"
    },
    {
        "SHAP value": 0.0214046849,
        "feature": "PREV_NAME_YIELD_GROUP_low_action_MEAN"
    },
    {
        "SHAP value": 0.0205137983,
        "feature": "POS_MONTHS_BALANCE_SIZE"
    },
    {
        "SHAP value": 0.0199533611,
        "feature": "BURO_AMT_CREDIT_SUM_DEBT_MEAN"
    },
    {
        "SHAP value": 0.0184082569,
        "feature": "FLAG_DOCUMENT_3"
    },
    {
        "SHAP value": 0.0181795501,
        "feature": "PREV_AMT_DOWN_PAYMENT_MAX"
    },
    {
        "SHAP value": 0.0174775107,
        "feature": "APPROVED_AMT_CREDIT_MIN"
    },
    {
        "SHAP value": 0.0157442224,
        "feature": "PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN"
    },
    {
        "SHAP value": 0.0153667847,
        "feature": "NAME_CONTRACT_TYPE_Cash loans"
    },
    {
        "SHAP value": 0.0146501331,
        "feature": "ACTIVE_DAYS_CREDIT_MEAN"
    },
    {
        "SHAP value": 0.0139874978,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN"
    },
    {
        "SHAP value": 0.0135354153,
        "feature": "BURO_DAYS_CREDIT_MEAN"
    },
    {
        "SHAP value": 0.0133648673,
        "feature": "INSTAL_DBD_MAX"
    },
    {
        "SHAP value": 0.013215962,
        "feature": "INSTAL_DAYS_ENTRY_PAYMENT_SUM"
    },
    {
        "SHAP value": 0.0128001824,
        "feature": "BURO_DAYS_CREDIT_MAX"
    },
    {
        "SHAP value": 0.0127355477,
        "feature": "INSTAL_AMT_PAYMENT_MEAN"
    },
    {
        "SHAP value": 0.0120964077,
        "feature": "BURO_CREDIT_TYPE_Mortgage_MEAN"
    },
    {
        "SHAP value": 0.0120170277,
        "feature": "AMT_REQ_CREDIT_BUREAU_QRT"
    },
    {
        "SHAP value": 0.0117095948,
        "feature": "INCOME_CREDIT_PERC"
    },
    {
        "SHAP value": 0.0107838568,
        "feature": "INSTAL_AMT_INSTALMENT_SUM"
    },
    {
        "SHAP value": 0.0106930731,
        "feature": "INSTAL_PAYMENT_PERC_SUM"
    },
    {
        "SHAP value": 0.010487066,
        "feature": "POS_NAME_CONTRACT_STATUS_Active_MEAN"
    },
    {
        "SHAP value": 0.0102665948,
        "feature": "BURO_CREDIT_ACTIVE_Closed_MEAN"
    },
    {
        "SHAP value": 0.0102465152,
        "feature": "PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN"
    },
    {
        "SHAP value": 0.0092487361,
        "feature": "OCCUPATION_TYPE_Core staff"
    },
    {
        "SHAP value": 0.0091846628,
        "feature": "ACTIVE_AMT_ANNUITY_MEAN"
    },
    {
        "SHAP value": 0.0090855412,
        "feature": "APPROVED_DAYS_DECISION_MEAN"
    },
    {
        "SHAP value": 0.0087059336,
        "feature": "APPROVED_AMT_ANNUITY_MAX"
    },
    {
        "SHAP value": 0.0086981075,
        "feature": "ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM"
    },
    {
        "SHAP value": 0.0086821348,
        "feature": "APPROVED_AMT_GOODS_PRICE_MAX"
    },
    {
        "SHAP value": 0.0081628163,
        "feature": "CLOSED_DAYS_CREDIT_MAX"
    },
    {
        "SHAP value": 0.0079977304,
        "feature": "PREV_AMT_ANNUITY_MEAN"
    },
    {
        "SHAP value": 0.0079657739,
        "feature": "POS_SK_DPD_DEF_MAX"
    },
    {
        "SHAP value": 0.0077159581,
        "feature": "PREV_NAME_GOODS_CATEGORY_Furniture_MEAN"
    },
    {
        "SHAP value": 0.0076870753,
        "feature": "PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN"
    },
    {
        "SHAP value": 0.0076098195,
        "feature": "PREV_DAYS_DECISION_MAX"
    },
    {
        "SHAP value": 0.0075931691,
        "feature": "PREV_APP_CREDIT_PERC_MAX"
    },
    {
        "SHAP value": 0.0072941946,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN"
    },
    {
        "SHAP value": 0.0071018299,
        "feature": "NAME_INCOME_TYPE_State servant"
    },
    {
        "SHAP value": 0.0066210969,
        "feature": "LIVINGAPARTMENTS_MEDI"
    },
    {
        "SHAP value": 0.0063139273,
        "feature": "PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN"
    },
    {
        "SHAP value": 0.0062118975,
        "feature": "FLAG_PHONE"
    },
    {
        "SHAP value": 0.0061542823,
        "feature": "BURO_AMT_CREDIT_SUM_LIMIT_MEAN"
    },
    {
        "SHAP value": 0.0056123631,
        "feature": "INSTAL_AMT_PAYMENT_MIN"
    },
    {
        "SHAP value": 0.0054803017,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN"
    },
    {
        "SHAP value": 0.0054565117,
        "feature": "ACTIVE_DAYS_CREDIT_VAR"
    },
    {
        "SHAP value": 0.0050968915,
        "feature": "PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN"
    },
    {
        "SHAP value": 0.0050753808,
        "feature": "FLAG_OWN_CAR"
    },
    {
        "SHAP value": 0.0049450904,
        "feature": "PREV_NAME_PORTFOLIO_POS_MEAN"
    },
    {
        "SHAP value": 0.0048592874,
        "feature": "PREV_RATE_DOWN_PAYMENT_MEAN"
    },
    {
        "SHAP value": 0.0047960297,
        "feature": "APPROVED_APP_CREDIT_PERC_MAX"
    },
    {
        "SHAP value": 0.0047339459,
        "feature": "DAYS_EMPLOYED"
    },
    {
        "SHAP value": 0.0043580617,
        "feature": "PREV_NAME_YIELD_GROUP_low_normal_MEAN"
    },
    {
        "SHAP value": 0.0043200903,
        "feature": "FLOORSMAX_AVG"
    },
    {
        "SHAP value": 0.0042490091,
        "feature": "NAME_INCOME_TYPE_Working"
    },
    {
        "SHAP value": 0.0042269956,
        "feature": "APPROVED_AMT_GOODS_PRICE_MIN"
    },
    {
        "SHAP value": 0.0040234828,
        "feature": "YEARS_BEGINEXPLUATATION_MEDI"
    },
    {
        "SHAP value": 0.0037841799,
        "feature": "PREV_NAME_GOODS_CATEGORY_Mobile_MEAN"
    },
    {
        "SHAP value": 0.0037465869,
        "feature": "BURO_CREDIT_TYPE_Car loan_MEAN"
    },
    {
        "SHAP value": 0.0036310286,
        "feature": "PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN"
    },
    {
        "SHAP value": 0.0035086231,
        "feature": "PREV_CHANNEL_TYPE_Credit and cash offices_MEAN"
    },
    {
        "SHAP value": 0.0034875563,
        "feature": "BURO_DAYS_CREDIT_MIN"
    },
    {
        "SHAP value": 0.003349273,
        "feature": "WEEKDAY_APPR_PROCESS_START_MONDAY"
    },
    {
        "SHAP value": 0.003326327,
        "feature": "PREV_HOUR_APPR_PROCESS_START_MAX"
    },
    {
        "SHAP value": 0.0032540373,
        "feature": "BURO_AMT_CREDIT_SUM_MAX"
    },
    {
        "SHAP value": 0.0031532313,
        "feature": "PREV_NAME_CONTRACT_STATUS_Canceled_MEAN"
    },
    {
        "SHAP value": 0.0030918936,
        "feature": "PREV_AMT_ANNUITY_MIN"
    },
    {
        "SHAP value": 0.003008497,
        "feature": "BURO_AMT_ANNUITY_MAX"
    },
    {
        "SHAP value": 0.003002033,
        "feature": "APPROVED_APP_CREDIT_PERC_VAR"
    },
    {
        "SHAP value": 0.0028940839,
        "feature": "PREV_RATE_DOWN_PAYMENT_MAX"
    },
    {
        "SHAP value": 0.0028598148,
        "feature": "BASEMENTAREA_MEDI"
    },
    {
        "SHAP value": 0.0027885636,
        "feature": "FLOORSMAX_MODE"
    },
    {
        "SHAP value": 0.0025926489,
        "feature": "TOTALAREA_MODE"
    },
    {
        "SHAP value": 0.0025913323,
        "feature": "PREV_NAME_PRODUCT_TYPE_x-sell_MEAN"
    },
    {
        "SHAP value": 0.0025118909,
        "feature": "APPROVED_HOUR_APPR_PROCESS_START_MAX"
    },
    {
        "SHAP value": 0.0023898056,
        "feature": "ACTIVE_MONTHS_BALANCE_SIZE_MEAN"
    },
    {
        "SHAP value": 0.0023799212,
        "feature": "BURO_AMT_CREDIT_SUM_DEBT_MAX"
    },
    {
        "SHAP value": 0.0023762545,
        "feature": "PREV_NAME_CLIENT_TYPE_Repeater_MEAN"
    },
    {
        "SHAP value": 0.0023683285,
        "feature": "PREV_AMT_GOODS_PRICE_MAX"
    },
    {
        "SHAP value": 0.0023331559,
        "feature": "APPROVED_DAYS_DECISION_MIN"
    },
    {
        "SHAP value": 0.0023325992,
        "feature": "BURO_STATUS_X_MEAN_MEAN"
    },
    {
        "SHAP value": 0.0022847215,
        "feature": "OCCUPATION_TYPE_High skill tech staff"
    },
    {
        "SHAP value": 0.0022206818,
        "feature": "BURO_CREDIT_ACTIVE_Active_MEAN"
    },
    {
        "SHAP value": 0.0022091384,
        "feature": "ORGANIZATION_TYPE_School"
    },
    {
        "SHAP value": 0.0021795067,
        "feature": "ACTIVE_AMT_CREDIT_SUM_MEAN"
    },
    {
        "SHAP value": 0.0021780199,
        "feature": "ORGANIZATION_TYPE_Military"
    },
    {
        "SHAP value": 0.0020939684,
        "feature": "APPROVED_AMT_DOWN_PAYMENT_MIN"
    },
    {
        "SHAP value": 0.0020792977,
        "feature": "YEARS_BEGINEXPLUATATION_AVG"
    },
    {
        "SHAP value": 0.002033199,
        "feature": "ORGANIZATION_TYPE_Industry: type 9"
    },
    {
        "SHAP value": 0.0020014857,
        "feature": "PREV_RATE_DOWN_PAYMENT_MIN"
    },
    {
        "SHAP value": 0.0019697086,
        "feature": "APPROVED_RATE_DOWN_PAYMENT_MIN"
    },
    {
        "SHAP value": 0.0019220218,
        "feature": "CC_AMT_BALANCE_MAX"
    },
    {
        "SHAP value": 0.00190745,
        "feature": "ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN"
    },
    {
        "SHAP value": 0.0018543102,
        "feature": "COMMONAREA_MODE"
    },
    {
        "SHAP value": 0.0018187896,
        "feature": "CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN"
    },
    {
        "SHAP value": 0.0018039341,
        "feature": "PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN"
    },
    {
        "SHAP value": 0.001790181,
        "feature": "PREV_CODE_REJECT_REASON_SCO_MEAN"
    },
    {
        "SHAP value": 0.0017426013,
        "feature": "FLAG_DOCUMENT_16"
    },
    {
        "SHAP value": 0.0017396735,
        "feature": "WEEKDAY_APPR_PROCESS_START_TUESDAY"
    },
    {
        "SHAP value": 0.0016955013,
        "feature": "POS_COUNT"
    },
    {
        "SHAP value": 0.0016506486,
        "feature": "APPROVED_RATE_DOWN_PAYMENT_MAX"
    },
    {
        "SHAP value": 0.0016423768,
        "feature": "OBS_30_CNT_SOCIAL_CIRCLE"
    },
    {
        "SHAP value": 0.00160388,
        "feature": "PREV_AMT_DOWN_PAYMENT_MEAN"
    },
    {
        "SHAP value": 0.0016030433,
        "feature": "OCCUPATION_TYPE_Accountants"
    },
    {
        "SHAP value": 0.0015935944,
        "feature": "BASEMENTAREA_AVG"
    },
    {
        "SHAP value": 0.0015892774,
        "feature": "FLAG_DOCUMENT_18"
    },
    {
        "SHAP value": 0.001542901,
        "feature": "CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN"
    },
    {
        "SHAP value": 0.0015316884,
        "feature": "INSTAL_PAYMENT_PERC_VAR"
    },
    {
        "SHAP value": 0.0014987247,
        "feature": "APPROVED_AMT_APPLICATION_MAX"
    },
    {
        "SHAP value": 0.0014767664,
        "feature": "CC_AMT_PAYMENT_CURRENT_MEAN"
    },
    {
        "SHAP value": 0.0014386232,
        "feature": "WEEKDAY_APPR_PROCESS_START_SUNDAY"
    },
    {
        "SHAP value": 0.0014178723,
        "feature": "INSTAL_COUNT"
    },
    {
        "SHAP value": 0.001411931,
        "feature": "PREV_CHANNEL_TYPE_Country-wide_MEAN"
    },
    {
        "SHAP value": 0.0014001699,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN"
    },
    {
        "SHAP value": 0.0013356204,
        "feature": "REFUSED_APP_CREDIT_PERC_VAR"
    },
    {
        "SHAP value": 0.0012812676,
        "feature": "YEARS_BEGINEXPLUATATION_MODE"
    },
    {
        "SHAP value": 0.0012721419,
        "feature": "FONDKAPREMONT_MODE_reg oper spec account"
    },
    {
        "SHAP value": 0.001242101,
        "feature": "APPROVED_AMT_ANNUITY_MIN"
    },
    {
        "SHAP value": 0.0012338273,
        "feature": "REFUSED_AMT_GOODS_PRICE_MEAN"
    },
    {
        "SHAP value": 0.0012150386,
        "feature": "PREV_CHANNEL_TYPE_Regional / Local_MEAN"
    },
    {
        "SHAP value": 0.0011166797,
        "feature": "PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN"
    },
    {
        "SHAP value": 0.0011052772,
        "feature": "BURO_MONTHS_BALANCE_SIZE_SUM"
    },
    {
        "SHAP value": 0.0010569247,
        "feature": "BURO_AMT_CREDIT_MAX_OVERDUE_MEAN"
    },
    {
        "SHAP value": 0.0010329721,
        "feature": "CLOSED_AMT_ANNUITY_MEAN"
    },
    {
        "SHAP value": 0.001022699,
        "feature": "CC_AMT_PAYMENT_CURRENT_SUM"
    },
    {
        "SHAP value": 0.0009650407,
        "feature": "NAME_HOUSING_TYPE_Office apartment"
    },
    {
        "SHAP value": 0.0009648334,
        "feature": "CC_AMT_PAYMENT_CURRENT_MIN"
    },
    {
        "SHAP value": 0.00095239,
        "feature": "INSTAL_DPD_SUM"
    },
    {
        "SHAP value": 0.0009257602,
        "feature": "AMT_REQ_CREDIT_BUREAU_YEAR"
    },
    {
        "SHAP value": 0.0009159586,
        "feature": "INSTAL_AMT_INSTALMENT_MEAN"
    },
    {
        "SHAP value": 0.0009075138,
        "feature": "LIVINGAREA_MEDI"
    },
    {
        "SHAP value": 0.000904048,
        "feature": "CC_NAME_CONTRACT_STATUS_Active_VAR"
    },
    {
        "SHAP value": 0.0008966734,
        "feature": "NONLIVINGAREA_MODE"
    },
    {
        "SHAP value": 0.0008573729,
        "feature": "PREV_PRODUCT_COMBINATION_Card Street_MEAN"
    },
    {
        "SHAP value": 0.0008430498,
        "feature": "CC_AMT_DRAWINGS_POS_CURRENT_SUM"
    },
    {
        "SHAP value": 0.000832338,
        "feature": "PREV_NAME_PORTFOLIO_Cash_MEAN"
    },
    {
        "SHAP value": 0.0008323352,
        "feature": "NAME_EDUCATION_TYPE_Incomplete higher"
    },
    {
        "SHAP value": 0.0008304675,
        "feature": "CC_AMT_RECEIVABLE_PRINCIPAL_MAX"
    },
    {
        "SHAP value": 0.000827625,
        "feature": "LIVINGAREA_AVG"
    },
    {
        "SHAP value": 0.0008118217,
        "feature": "PREV_DAYS_DECISION_MIN"
    },
    {
        "SHAP value": 0.0008056567,
        "feature": "PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN"
    },
    {
        "SHAP value": 0.0007982826,
        "feature": "PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN"
    },
    {
        "SHAP value": 0.000766029,
        "feature": "PREV_NAME_GOODS_CATEGORY_Gardening_MEAN"
    },
    {
        "SHAP value": 0.0007643506,
        "feature": "CC_AMT_INST_MIN_REGULARITY_SUM"
    },
    {
        "SHAP value": 0.0007563602,
        "feature": "CC_AMT_PAYMENT_TOTAL_CURRENT_SUM"
    },
    {
        "SHAP value": 0.0007256029,
        "feature": "ORGANIZATION_TYPE_Bank"
    },
    {
        "SHAP value": 0.0006992754,
        "feature": "FLAG_DOCUMENT_8"
    },
    {
        "SHAP value": 0.0006877385,
        "feature": "ENTRANCES_MEDI"
    },
    {
        "SHAP value": 0.0006624669,
        "feature": "ACTIVE_AMT_CREDIT_SUM_MAX"
    },
    {
        "SHAP value": 0.0006320038,
        "feature": "NAME_INCOME_TYPE_Commercial associate"
    },
    {
        "SHAP value": 0.0006250146,
        "feature": "FLAG_OWN_REALTY"
    },
    {
        "SHAP value": 0.0006125626,
        "feature": "CC_AMT_DRAWINGS_CURRENT_VAR"
    },
    {
        "SHAP value": 0.0006065713,
        "feature": "WALLSMATERIAL_MODE_Panel"
    },
    {
        "SHAP value": 0.0005946006,
        "feature": "NONLIVINGAREA_MEDI"
    },
    {
        "SHAP value": 0.0005933278,
        "feature": "CC_NAME_CONTRACT_STATUS_Signed_VAR"
    },
    {
        "SHAP value": 0.0005790308,
        "feature": "NAME_FAMILY_STATUS_Widow"
    },
    {
        "SHAP value": 0.000553899,
        "feature": "ORGANIZATION_TYPE_Medicine"
    },
    {
        "SHAP value": 0.0005474152,
        "feature": "NAME_TYPE_SUITE_Spouse, partner"
    },
    {
        "SHAP value": 0.0005431196,
        "feature": "CC_AMT_INST_MIN_REGULARITY_VAR"
    },
    {
        "SHAP value": 0.0005399323,
        "feature": "COMMONAREA_MEDI"
    },
    {
        "SHAP value": 0.0005295756,
        "feature": "PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN"
    },
    {
        "SHAP value": 0.0005281636,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN"
    },
    {
        "SHAP value": 0.0005276609,
        "feature": "WEEKDAY_APPR_PROCESS_START_SATURDAY"
    },
    {
        "SHAP value": 0.0005169588,
        "feature": "CC_CNT_INSTALMENT_MATURE_CUM_VAR"
    },
    {
        "SHAP value": 0.0005106679,
        "feature": "REGION_RATING_CLIENT_W_CITY"
    },
    {
        "SHAP value": 0.0005079002,
        "feature": "APPROVED_APP_CREDIT_PERC_MEAN"
    },
    {
        "SHAP value": 0.0004964902,
        "feature": "ORGANIZATION_TYPE_Police"
    },
    {
        "SHAP value": 0.0004861071,
        "feature": "LANDAREA_MODE"
    },
    {
        "SHAP value": 0.000482636,
        "feature": "BURO_DAYS_CREDIT_ENDDATE_MEAN"
    },
    {
        "SHAP value": 0.0004805382,
        "feature": "REFUSED_AMT_GOODS_PRICE_MAX"
    },
    {
        "SHAP value": 0.0004798322,
        "feature": "OBS_60_CNT_SOCIAL_CIRCLE"
    },
    {
        "SHAP value": 0.0004789814,
        "feature": "CC_SK_DPD_VAR"
    },
    {
        "SHAP value": 0.0004779887,
        "feature": "ACTIVE_DAYS_CREDIT_MIN"
    },
    {
        "SHAP value": 0.0004575236,
        "feature": "REFUSED_AMT_ANNUITY_MAX"
    },
    {
        "SHAP value": 0.0004564363,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Construction_MEAN"
    },
    {
        "SHAP value": 0.0004432177,
        "feature": "FLAG_EMAIL"
    },
    {
        "SHAP value": 0.0004349559,
        "feature": "PREV_NAME_TYPE_SUITE_Family_MEAN"
    },
    {
        "SHAP value": 0.0004239598,
        "feature": "INSTAL_DPD_MAX"
    },
    {
        "SHAP value": 0.0004207537,
        "feature": "CC_AMT_DRAWINGS_CURRENT_MIN"
    },
    {
        "SHAP value": 0.0004087157,
        "feature": "CC_AMT_PAYMENT_TOTAL_CURRENT_MAX"
    },
    {
        "SHAP value": 0.0003874109,
        "feature": "BURO_CREDIT_TYPE_Consumer credit_MEAN"
    },
    {
        "SHAP value": 0.0003842673,
        "feature": "OCCUPATION_TYPE_Medicine staff"
    },
    {
        "SHAP value": 0.0003666224,
        "feature": "YEARS_BUILD_MODE"
    },
    {
        "SHAP value": 0.0003483359,
        "feature": "PREV_NAME_TYPE_SUITE_Children_MEAN"
    },
    {
        "SHAP value": 0.0003164758,
        "feature": "CC_MONTHS_BALANCE_VAR"
    },
    {
        "SHAP value": 0.0003069392,
        "feature": "FLOORSMIN_MODE"
    },
    {
        "SHAP value": 0.0002971516,
        "feature": "CNT_CHILDREN"
    },
    {
        "SHAP value": 0.0002963858,
        "feature": "CC_CNT_INSTALMENT_MATURE_CUM_MEAN"
    },
    {
        "SHAP value": 0.0002759868,
        "feature": "APPROVED_RATE_DOWN_PAYMENT_MEAN"
    },
    {
        "SHAP value": 0.0002613292,
        "feature": "BURO_CREDIT_TYPE_Another type of loan_MEAN"
    },
    {
        "SHAP value": 0.0002564004,
        "feature": "REFUSED_AMT_GOODS_PRICE_MIN"
    },
    {
        "SHAP value": 0.0002540334,
        "feature": "AMT_REQ_CREDIT_BUREAU_MON"
    },
    {
        "SHAP value": 0.0002517576,
        "feature": "REFUSED_APP_CREDIT_PERC_MEAN"
    },
    {
        "SHAP value": 0.0002478561,
        "feature": "YEARS_BUILD_AVG"
    },
    {
        "SHAP value": 0.0002449876,
        "feature": "PREV_AMT_DOWN_PAYMENT_MIN"
    },
    {
        "SHAP value": 0.0002432328,
        "feature": "CC_AMT_PAYMENT_TOTAL_CURRENT_VAR"
    },
    {
        "SHAP value": 0.0002256917,
        "feature": "CC_SK_DPD_SUM"
    },
    {
        "SHAP value": 0.000213245,
        "feature": "ORGANIZATION_TYPE_Security Ministries"
    },
    {
        "SHAP value": 0.0002116887,
        "feature": "CC_AMT_PAYMENT_TOTAL_CURRENT_MIN"
    },
    {
        "SHAP value": 0.0002091845,
        "feature": "CC_AMT_CREDIT_LIMIT_ACTUAL_SUM"
    },
    {
        "SHAP value": 0.0001873573,
        "feature": "PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN"
    },
    {
        "SHAP value": 0.0001852969,
        "feature": "APPROVED_AMT_APPLICATION_MEAN"
    },
    {
        "SHAP value": 0.0001793347,
        "feature": "PREV_CODE_REJECT_REASON_VERIF_MEAN"
    },
    {
        "SHAP value": 0.0001748302,
        "feature": "CC_NAME_CONTRACT_STATUS_Active_MEAN"
    },
    {
        "SHAP value": 0.0001701419,
        "feature": "CC_AMT_INST_MIN_REGULARITY_MEAN"
    },
    {
        "SHAP value": 0.0001544121,
        "feature": "CLOSED_MONTHS_BALANCE_SIZE_SUM"
    },
    {
        "SHAP value": 0.0001510228,
        "feature": "CC_AMT_DRAWINGS_CURRENT_SUM"
    },
    {
        "SHAP value": 0.0001509893,
        "feature": "PREV_CHANNEL_TYPE_Contact center_MEAN"
    },
    {
        "SHAP value": 0.0001437939,
        "feature": "CC_AMT_CREDIT_LIMIT_ACTUAL_MIN"
    },
    {
        "SHAP value": 0.0001419016,
        "feature": "CC_CNT_DRAWINGS_POS_CURRENT_SUM"
    },
    {
        "SHAP value": 0.0001319259,
        "feature": "CC_COUNT"
    },
    {
        "SHAP value": 0.0001242763,
        "feature": "WALLSMATERIAL_MODE_Block"
    },
    {
        "SHAP value": 0.0001207548,
        "feature": "REFUSED_DAYS_DECISION_MIN"
    },
    {
        "SHAP value": 0.0001177101,
        "feature": "APPROVED_HOUR_APPR_PROCESS_START_MEAN"
    },
    {
        "SHAP value": 0.0001172159,
        "feature": "PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN"
    },
    {
        "SHAP value": 0.000106382,
        "feature": "CC_CNT_INSTALMENT_MATURE_CUM_MAX"
    },
    {
        "SHAP value": 0.0001038833,
        "feature": "CC_AMT_RECEIVABLE_PRINCIPAL_SUM"
    },
    {
        "SHAP value": 0.0001004197,
        "feature": "NAME_CONTRACT_TYPE_Revolving loans"
    },
    {
        "SHAP value": 9.77363e-05,
        "feature": "CC_MONTHS_BALANCE_MAX"
    },
    {
        "SHAP value": 9.52046e-05,
        "feature": "REFUSED_RATE_DOWN_PAYMENT_MEAN"
    },
    {
        "SHAP value": 8.94986e-05,
        "feature": "CC_AMT_DRAWINGS_POS_CURRENT_MEAN"
    },
    {
        "SHAP value": 7.71893e-05,
        "feature": "CLOSED_MONTHS_BALANCE_MAX_MAX"
    },
    {
        "SHAP value": 7.27972e-05,
        "feature": "CC_AMT_TOTAL_RECEIVABLE_VAR"
    },
    {
        "SHAP value": 6.61981e-05,
        "feature": "CC_MONTHS_BALANCE_MEAN"
    },
    {
        "SHAP value": 6.44637e-05,
        "feature": "FLAG_DOCUMENT_11"
    },
    {
        "SHAP value": 6.10453e-05,
        "feature": "COMMONAREA_AVG"
    },
    {
        "SHAP value": 5.71127e-05,
        "feature": "CC_SK_DPD_MAX"
    },
    {
        "SHAP value": 5.60747e-05,
        "feature": "ORGANIZATION_TYPE_Services"
    },
    {
        "SHAP value": 5.4044e-05,
        "feature": "BURO_CREDIT_DAY_OVERDUE_MAX"
    },
    {
        "SHAP value": 4.99437e-05,
        "feature": "FONDKAPREMONT_MODE_org spec account"
    },
    {
        "SHAP value": 4.98118e-05,
        "feature": "PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN"
    },
    {
        "SHAP value": 4.12005e-05,
        "feature": "NAME_TYPE_SUITE_nan"
    },
    {
        "SHAP value": 3.93126e-05,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN"
    },
    {
        "SHAP value": 3.59342e-05,
        "feature": "BURO_CREDIT_DAY_OVERDUE_MEAN"
    },
    {
        "SHAP value": 3.50216e-05,
        "feature": "CC_CNT_DRAWINGS_CURRENT_SUM"
    },
    {
        "SHAP value": 3.2424e-05,
        "feature": "PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN"
    },
    {
        "SHAP value": 2.71929e-05,
        "feature": "REFUSED_RATE_DOWN_PAYMENT_MAX"
    },
    {
        "SHAP value": 2.64626e-05,
        "feature": "LIVE_REGION_NOT_WORK_REGION"
    },
    {
        "SHAP value": 2.6281e-05,
        "feature": "CC_AMT_INST_MIN_REGULARITY_MAX"
    },
    {
        "SHAP value": 1.9523e-05,
        "feature": "CC_NAME_CONTRACT_STATUS_Active_SUM"
    },
    {
        "SHAP value": 1.90193e-05,
        "feature": "ORGANIZATION_TYPE_Government"
    },
    {
        "SHAP value": 1.58704e-05,
        "feature": "NAME_TYPE_SUITE_Family"
    },
    {
        "SHAP value": 1.22915e-05,
        "feature": "CLOSED_AMT_CREDIT_SUM_LIMIT_SUM"
    },
    {
        "SHAP value": 1.05673e-05,
        "feature": "PREV_NAME_TYPE_SUITE_Group of people_MEAN"
    },
    {
        "SHAP value": 8.8239e-06,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN"
    },
    {
        "SHAP value": 8.0846e-06,
        "feature": "OCCUPATION_TYPE_Private service staff"
    },
    {
        "SHAP value": 7.5922e-06,
        "feature": "PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN"
    },
    {
        "SHAP value": 5.4239e-06,
        "feature": "CC_MONTHS_BALANCE_MIN"
    },
    {
        "SHAP value": 4.1288e-06,
        "feature": "REG_CITY_NOT_WORK_CITY"
    },
    {
        "SHAP value": 3.8995e-06,
        "feature": "CC_CNT_INSTALMENT_MATURE_CUM_SUM"
    },
    {
        "SHAP value": 2.5503e-06,
        "feature": "CC_AMT_DRAWINGS_OTHER_CURRENT_SUM"
    },
    {
        "SHAP value": 1.7824e-06,
        "feature": "FONDKAPREMONT_MODE_reg oper account"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Signed_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Sent proposal_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Sent proposal_VAR"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_15"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_CODE_REJECT_REASON_SYSTEM_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_14"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Signed_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_19"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_13"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Sent proposal_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_12"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CLIENT_TYPE_XNA_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Animals_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Sent proposal_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Education_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Fitness_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_AMT_DRAWINGS_OTHER_CURRENT_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Refused_VAR"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_17"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Signed_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CONTRACT_TYPE_XNA_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_21"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Signed_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "AMT_REQ_CREDIT_BUREAU_HOUR"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_MOBIL"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_House Construction_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_20"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Homewares_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_9"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Refused_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_CNT_INSTALMENT_MATURE_CUM_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_PRODUCT_COMBINATION_nan_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Approved_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Approved_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Approved_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Approved_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Active_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Active_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_SK_DPD_DEF_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_SK_DPD_DEF_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_SK_DPD_DEF_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_SK_DPD_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_AMT_INST_MIN_REGULARITY_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Insurance_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "POS_NAME_CONTRACT_STATUS_Approved_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "POS_NAME_CONTRACT_STATUS_Canceled_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "POS_NAME_CONTRACT_STATUS_Demand_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "POS_NAME_CONTRACT_STATUS_XNA_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_CNT_DRAWINGS_OTHER_CURRENT_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_CNT_DRAWINGS_OTHER_CURRENT_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "REG_REGION_NOT_WORK_REGION"
    },
    {
        "SHAP value": 0.0,
        "feature": "REG_REGION_NOT_LIVE_REGION"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_CNT_DRAWINGS_OTHER_CURRENT_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_CONT_MOBILE"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_CNT_DRAWINGS_ATM_CURRENT_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_AMT_DRAWINGS_ATM_CURRENT_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_PRODUCT_COMBINATION_POS others without interest_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Approved_VAR"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Completed_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Completed_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Refused_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Medicine_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_10"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Other_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_EMP_PHONE"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Refused_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Tourism_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Refused_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_PORTFOLIO_Cars_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Demand_VAR"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_7"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_CHANNEL_TYPE_Car dealer_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_5"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_4"
    },
    {
        "SHAP value": 0.0,
        "feature": "FLAG_DOCUMENT_2"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Demand_SUM"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Demand_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Demand_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Demand_MIN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CC_NAME_CONTRACT_STATUS_Completed_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Weapon_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Transport: type 2"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_CURRENCY_currency 2_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Security"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_INCOME_TYPE_Maternity leave"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_University"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Religion"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_XNA"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Realtor"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_CURRENCY_currency 3_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Postal"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Managers"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_INCOME_TYPE_Businessman"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Mobile"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_INCOME_TYPE_Pensioner"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_CURRENCY_currency 1_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Legal Services"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_ACTIVE_Bad debt_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_HOUSING_TYPE_Co-op apartment"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Insurance"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Realty agents"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 7"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 6"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 5"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 4"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Telecom"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Trade: type 1"
    },
    {
        "SHAP value": 0.0,
        "feature": "HOUSETYPE_MODE_block of flats"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_EDUCATION_TYPE_Academic degree"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Transport: type 1"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Unknown type of loan_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_STATUS_5_MEAN_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Real estate loan_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Trade: type 6"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Mobile operator loan_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Trade: type 5"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Trade: type 4"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_CURRENCY_currency 4_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ACTIVE_CREDIT_DAY_OVERDUE_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "ACTIVE_CREDIT_DAY_OVERDUE_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_INCOME_TYPE_Unemployed"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Loan for business development_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_INCOME_TYPE_Student"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Trade: type 3"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Interbank credit_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Trade: type 2"
    },
    {
        "SHAP value": 0.0,
        "feature": "BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_FAMILY_STATUS_Unknown"
    },
    {
        "SHAP value": 0.0,
        "feature": "CLOSED_CREDIT_DAY_OVERDUE_MAX"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 8"
    },
    {
        "SHAP value": 0.0,
        "feature": "HOUSETYPE_MODE_terraced house"
    },
    {
        "SHAP value": 0.0,
        "feature": "EMERGENCYSTATE_MODE_nan"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Housing"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Hotel"
    },
    {
        "SHAP value": 0.0,
        "feature": "HOUSETYPE_MODE_nan"
    },
    {
        "SHAP value": 0.0,
        "feature": "EMERGENCYSTATE_MODE_No"
    },
    {
        "SHAP value": 0.0,
        "feature": "EMERGENCYSTATE_MODE_Yes"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Electricity"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Culture"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Cleaning"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Business Entity Type 1"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Agriculture"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Advertising"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 1"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Cleaning staff"
    },
    {
        "SHAP value": 0.0,
        "feature": "WEEKDAY_APPR_PROCESS_START_THURSDAY"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Low-skill Laborers"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Secretaries"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_IT staff"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_HR staff"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_TYPE_SUITE_Other_A"
    },
    {
        "SHAP value": 0.0,
        "feature": "NAME_TYPE_SUITE_Group of people"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Security staff"
    },
    {
        "SHAP value": 0.0,
        "feature": "OCCUPATION_TYPE_Cooking staff"
    },
    {
        "SHAP value": 0.0,
        "feature": "WALLSMATERIAL_MODE_Wooden"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Emergency"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 10"
    },
    {
        "SHAP value": 0.0,
        "feature": "CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "CLOSED_CREDIT_DAY_OVERDUE_MEAN"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 2"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 13"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 12"
    },
    {
        "SHAP value": 0.0,
        "feature": "ORGANIZATION_TYPE_Industry: type 11"
    },
    {
        "SHAP value": 0.0,
        "feature": "WALLSMATERIAL_MODE_Monolithic"
    },
    {
        "SHAP value": 0.0,
        "feature": "WALLSMATERIAL_MODE_Mixed"
    },
    {
        "SHAP value": 0.0,
        "feature": "CLOSED_CNT_CREDIT_PROLONG_SUM"
    },
    {
        "SHAP value": -3.143e-07,
        "feature": "BURO_CNT_CREDIT_PROLONG_SUM"
    },
    {
        "SHAP value": -3.5229e-06,
        "feature": "NONLIVINGAPARTMENTS_AVG"
    },
    {
        "SHAP value": -4.1949e-06,
        "feature": "PREV_CODE_REJECT_REASON_CLIENT_MEAN"
    },
    {
        "SHAP value": -1.29897e-05,
        "feature": "ACTIVE_CNT_CREDIT_PROLONG_SUM"
    },
    {
        "SHAP value": -1.30442e-05,
        "feature": "CC_NAME_CONTRACT_STATUS_Completed_SUM"
    },
    {
        "SHAP value": -1.34e-05,
        "feature": "FONDKAPREMONT_MODE_not specified"
    },
    {
        "SHAP value": -1.34014e-05,
        "feature": "REFUSED_AMT_APPLICATION_MIN"
    },
    {
        "SHAP value": -1.35585e-05,
        "feature": "ORGANIZATION_TYPE_Business Entity Type 2"
    },
    {
        "SHAP value": -1.3814e-05,
        "feature": "CC_NAME_CONTRACT_STATUS_Completed_VAR"
    },
    {
        "SHAP value": -1.74302e-05,
        "feature": "CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN"
    },
    {
        "SHAP value": -2.15329e-05,
        "feature": "FLAG_DOCUMENT_6"
    },
    {
        "SHAP value": -2.17677e-05,
        "feature": "FLOORSMIN_MEDI"
    },
    {
        "SHAP value": -2.18561e-05,
        "feature": "PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN"
    },
    {
        "SHAP value": -2.80381e-05,
        "feature": "POS_SK_DPD_MAX"
    },
    {
        "SHAP value": -3.14824e-05,
        "feature": "ORGANIZATION_TYPE_Transport: type 4"
    },
    {
        "SHAP value": -3.8102e-05,
        "feature": "PREV_NAME_TYPE_SUITE_Other_A_MEAN"
    },
    {
        "SHAP value": -3.8543e-05,
        "feature": "PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN"
    },
    {
        "SHAP value": -4.38363e-05,
        "feature": "CC_AMT_DRAWINGS_OTHER_CURRENT_MAX"
    },
    {
        "SHAP value": -4.46893e-05,
        "feature": "NAME_HOUSING_TYPE_With parents"
    },
    {
        "SHAP value": -4.66057e-05,
        "feature": "CC_AMT_DRAWINGS_POS_CURRENT_MIN"
    },
    {
        "SHAP value": -4.72705e-05,
        "feature": "BURO_STATUS_3_MEAN_MEAN"
    },
    {
        "SHAP value": -4.79298e-05,
        "feature": "NAME_TYPE_SUITE_Children"
    },
    {
        "SHAP value": -4.84489e-05,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN"
    },
    {
        "SHAP value": -4.86089e-05,
        "feature": "CC_SK_DPD_DEF_VAR"
    },
    {
        "SHAP value": -5.36772e-05,
        "feature": "NONLIVINGAPARTMENTS_MODE"
    },
    {
        "SHAP value": -5.51835e-05,
        "feature": "ORGANIZATION_TYPE_Trade: type 7"
    },
    {
        "SHAP value": -5.62057e-05,
        "feature": "BURO_DAYS_CREDIT_ENDDATE_MIN"
    },
    {
        "SHAP value": -5.62802e-05,
        "feature": "INSTAL_PAYMENT_PERC_MAX"
    },
    {
        "SHAP value": -5.87539e-05,
        "feature": "CC_AMT_DRAWINGS_CURRENT_MAX"
    },
    {
        "SHAP value": -6.10494e-05,
        "feature": "NAME_FAMILY_STATUS_Civil marriage"
    },
    {
        "SHAP value": -6.20973e-05,
        "feature": "CC_AMT_DRAWINGS_CURRENT_MEAN"
    },
    {
        "SHAP value": -6.22546e-05,
        "feature": "CNT_FAM_MEMBERS"
    },
    {
        "SHAP value": -6.28762e-05,
        "feature": "ORGANIZATION_TYPE_Restaurant"
    },
    {
        "SHAP value": -6.98448e-05,
        "feature": "PREV_CODE_REJECT_REASON_XNA_MEAN"
    },
    {
        "SHAP value": -7.09015e-05,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN"
    },
    {
        "SHAP value": -7.37087e-05,
        "feature": "CLOSED_AMT_CREDIT_SUM_DEBT_SUM"
    },
    {
        "SHAP value": -7.39241e-05,
        "feature": "BURO_STATUS_2_MEAN_MEAN"
    },
    {
        "SHAP value": -7.68313e-05,
        "feature": "NAME_HOUSING_TYPE_Rented apartment"
    },
    {
        "SHAP value": -7.9442e-05,
        "feature": "CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN"
    },
    {
        "SHAP value": -8.07894e-05,
        "feature": "CC_AMT_CREDIT_LIMIT_ACTUAL_MAX"
    },
    {
        "SHAP value": -8.30251e-05,
        "feature": "PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN"
    },
    {
        "SHAP value": -8.35346e-05,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN"
    },
    {
        "SHAP value": -8.61993e-05,
        "feature": "NAME_TYPE_SUITE_Other_B"
    },
    {
        "SHAP value": -8.62006e-05,
        "feature": "CC_AMT_BALANCE_SUM"
    },
    {
        "SHAP value": -9.1021e-05,
        "feature": "CC_CNT_DRAWINGS_POS_CURRENT_VAR"
    },
    {
        "SHAP value": -9.17111e-05,
        "feature": "CC_CNT_DRAWINGS_ATM_CURRENT_MAX"
    },
    {
        "SHAP value": -9.44645e-05,
        "feature": "BURO_STATUS_4_MEAN_MEAN"
    },
    {
        "SHAP value": -9.51738e-05,
        "feature": "CC_CNT_DRAWINGS_OTHER_CURRENT_VAR"
    },
    {
        "SHAP value": -9.54617e-05,
        "feature": "PREV_NAME_PORTFOLIO_XNA_MEAN"
    },
    {
        "SHAP value": -9.77569e-05,
        "feature": "ELEVATORS_MEDI"
    },
    {
        "SHAP value": -0.0001020669,
        "feature": "CC_CNT_DRAWINGS_CURRENT_MIN"
    },
    {
        "SHAP value": -0.0001024194,
        "feature": "WALLSMATERIAL_MODE_nan"
    },
    {
        "SHAP value": -0.0001044313,
        "feature": "NAME_TYPE_SUITE_Unaccompanied"
    },
    {
        "SHAP value": -0.0001103114,
        "feature": "HOUSETYPE_MODE_specific housing"
    },
    {
        "SHAP value": -0.0001112973,
        "feature": "OCCUPATION_TYPE_Waiters/barmen staff"
    },
    {
        "SHAP value": -0.0001201237,
        "feature": "DAYS_EMPLOYED_PERC"
    },
    {
        "SHAP value": -0.0001203853,
        "feature": "FLOORSMIN_AVG"
    },
    {
        "SHAP value": -0.0001316788,
        "feature": "PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN"
    },
    {
        "SHAP value": -0.0001370642,
        "feature": "REFUSED_AMT_DOWN_PAYMENT_MEAN"
    },
    {
        "SHAP value": -0.0001383306,
        "feature": "CC_AMT_DRAWINGS_POS_CURRENT_MAX"
    },
    {
        "SHAP value": -0.0001394857,
        "feature": "WEEKDAY_APPR_PROCESS_START_FRIDAY"
    },
    {
        "SHAP value": -0.000143398,
        "feature": "CC_AMT_TOTAL_RECEIVABLE_SUM"
    },
    {
        "SHAP value": -0.0001464863,
        "feature": "NAME_FAMILY_STATUS_Separated"
    },
    {
        "SHAP value": -0.0001540461,
        "feature": "LIVINGAREA_MODE"
    },
    {
        "SHAP value": -0.0001601316,
        "feature": "PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN"
    },
    {
        "SHAP value": -0.0001685448,
        "feature": "REFUSED_RATE_DOWN_PAYMENT_MIN"
    },
    {
        "SHAP value": -0.0001688418,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Industry_MEAN"
    },
    {
        "SHAP value": -0.0001710317,
        "feature": "FONDKAPREMONT_MODE_nan"
    },
    {
        "SHAP value": -0.0001714489,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN"
    },
    {
        "SHAP value": -0.0001725017,
        "feature": "ORGANIZATION_TYPE_Other"
    },
    {
        "SHAP value": -0.0001740415,
        "feature": "CC_SK_DPD_DEF_MEAN"
    },
    {
        "SHAP value": -0.0001798279,
        "feature": "REFUSED_HOUR_APPR_PROCESS_START_MAX"
    },
    {
        "SHAP value": -0.0001874234,
        "feature": "CC_CNT_DRAWINGS_ATM_CURRENT_SUM"
    },
    {
        "SHAP value": -0.000195984,
        "feature": "WALLSMATERIAL_MODE_Others"
    },
    {
        "SHAP value": -0.0001993844,
        "feature": "FLOORSMAX_MEDI"
    },
    {
        "SHAP value": -0.000201147,
        "feature": "BURO_MONTHS_BALANCE_MAX_MAX"
    },
    {
        "SHAP value": -0.0002062877,
        "feature": "CC_AMT_RECEIVABLE_PRINCIPAL_VAR"
    },
    {
        "SHAP value": -0.0002077473,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN"
    },
    {
        "SHAP value": -0.0002082135,
        "feature": "CC_CNT_DRAWINGS_POS_CURRENT_MIN"
    },
    {
        "SHAP value": -0.0002113831,
        "feature": "PREV_NAME_TYPE_SUITE_Other_B_MEAN"
    },
    {
        "SHAP value": -0.0002177271,
        "feature": "PREV_PRODUCT_COMBINATION_POS household without interest_MEAN"
    },
    {
        "SHAP value": -0.0002200243,
        "feature": "ORGANIZATION_TYPE_Industry: type 3"
    },
    {
        "SHAP value": -0.0002224751,
        "feature": "OCCUPATION_TYPE_Sales staff"
    },
    {
        "SHAP value": -0.000226235,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN"
    },
    {
        "SHAP value": -0.0002272715,
        "feature": "AMT_REQ_CREDIT_BUREAU_DAY"
    },
    {
        "SHAP value": -0.0002314111,
        "feature": "REFUSED_CNT_PAYMENT_SUM"
    },
    {
        "SHAP value": -0.000239555,
        "feature": "CC_MONTHS_BALANCE_SUM"
    },
    {
        "SHAP value": -0.0002498276,
        "feature": "CC_AMT_DRAWINGS_OTHER_CURRENT_VAR"
    },
    {
        "SHAP value": -0.0002525438,
        "feature": "CC_AMT_TOTAL_RECEIVABLE_MIN"
    },
    {
        "SHAP value": -0.0002563488,
        "feature": "BURO_DAYS_CREDIT_VAR"
    },
    {
        "SHAP value": -0.0002592217,
        "feature": "AMT_REQ_CREDIT_BUREAU_WEEK"
    },
    {
        "SHAP value": -0.0002607341,
        "feature": "NAME_HOUSING_TYPE_Municipal apartment"
    },
    {
        "SHAP value": -0.0002620532,
        "feature": "CC_AMT_CREDIT_LIMIT_ACTUAL_VAR"
    },
    {
        "SHAP value": -0.0002785405,
        "feature": "CLOSED_AMT_CREDIT_SUM_DEBT_MEAN"
    },
    {
        "SHAP value": -0.000279947,
        "feature": "LIVINGAPARTMENTS_MODE"
    },
    {
        "SHAP value": -0.0002901908,
        "feature": "CC_AMT_DRAWINGS_ATM_CURRENT_MAX"
    },
    {
        "SHAP value": -0.0002998164,
        "feature": "CC_AMT_TOTAL_RECEIVABLE_MAX"
    },
    {
        "SHAP value": -0.0003012525,
        "feature": "PREV_CODE_REJECT_REASON_SCOFR_MEAN"
    },
    {
        "SHAP value": -0.0003034284,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN"
    },
    {
        "SHAP value": -0.0003049573,
        "feature": "REFUSED_AMT_CREDIT_MAX"
    },
    {
        "SHAP value": -0.0003160521,
        "feature": "WEEKDAY_APPR_PROCESS_START_WEDNESDAY"
    },
    {
        "SHAP value": -0.0003248745,
        "feature": "CC_AMT_RECEIVABLE_PRINCIPAL_MIN"
    },
    {
        "SHAP value": -0.0003289283,
        "feature": "REFUSED_AMT_DOWN_PAYMENT_MAX"
    },
    {
        "SHAP value": -0.0003403518,
        "feature": "ACTIVE_AMT_CREDIT_SUM_DEBT_MAX"
    },
    {
        "SHAP value": -0.0003491371,
        "feature": "CC_AMT_RECIVABLE_MIN"
    },
    {
        "SHAP value": -0.000359085,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN"
    },
    {
        "SHAP value": -0.0003668264,
        "feature": "PREV_DAYS_DECISION_MEAN"
    },
    {
        "SHAP value": -0.0003750037,
        "feature": "PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN"
    },
    {
        "SHAP value": -0.0003789753,
        "feature": "CC_AMT_RECIVABLE_SUM"
    },
    {
        "SHAP value": -0.0003926672,
        "feature": "PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN"
    },
    {
        "SHAP value": -0.0003971599,
        "feature": "CC_SK_DPD_MEAN"
    },
    {
        "SHAP value": -0.000424727,
        "feature": "CC_AMT_PAYMENT_CURRENT_VAR"
    },
    {
        "SHAP value": -0.0004257844,
        "feature": "YEARS_BUILD_MEDI"
    },
    {
        "SHAP value": -0.0004304756,
        "feature": "LIVE_CITY_NOT_WORK_CITY"
    },
    {
        "SHAP value": -0.0004392184,
        "feature": "APPROVED_AMT_CREDIT_MAX"
    },
    {
        "SHAP value": -0.0004444961,
        "feature": "CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN"
    },
    {
        "SHAP value": -0.0004541291,
        "feature": "PREV_NAME_PRODUCT_TYPE_XNA_MEAN"
    },
    {
        "SHAP value": -0.0004551547,
        "feature": "REFUSED_AMT_DOWN_PAYMENT_MIN"
    },
    {
        "SHAP value": -0.0004650078,
        "feature": "PREV_PRODUCT_COMBINATION_POS other with interest_MEAN"
    },
    {
        "SHAP value": -0.0004936176,
        "feature": "LIVINGAPARTMENTS_AVG"
    },
    {
        "SHAP value": -0.0004986098,
        "feature": "CC_AMT_RECIVABLE_VAR"
    },
    {
        "SHAP value": -0.000502954,
        "feature": "PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN"
    },
    {
        "SHAP value": -0.0005035061,
        "feature": "CC_CNT_DRAWINGS_POS_CURRENT_MEAN"
    },
    {
        "SHAP value": -0.0005086636,
        "feature": "CC_AMT_DRAWINGS_ATM_CURRENT_VAR"
    },
    {
        "SHAP value": -0.0005342254,
        "feature": "REFUSED_AMT_CREDIT_MEAN"
    },
    {
        "SHAP value": -0.0005425672,
        "feature": "APPROVED_HOUR_APPR_PROCESS_START_MIN"
    },
    {
        "SHAP value": -0.0005500613,
        "feature": "CC_AMT_DRAWINGS_ATM_CURRENT_SUM"
    },
    {
        "SHAP value": -0.0005512826,
        "feature": "CC_AMT_PAYMENT_CURRENT_MAX"
    },
    {
        "SHAP value": -0.0005593345,
        "feature": "ENTRANCES_MODE"
    },
    {
        "SHAP value": -0.000560479,
        "feature": "PREV_AMT_CREDIT_MIN"
    },
    {
        "SHAP value": -0.0005616276,
        "feature": "PREV_NAME_SELLER_INDUSTRY_XNA_MEAN"
    },
    {
        "SHAP value": -0.0005716429,
        "feature": "PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN"
    },
    {
        "SHAP value": -0.0005787393,
        "feature": "CC_AMT_BALANCE_VAR"
    },
    {
        "SHAP value": -0.0005832559,
        "feature": "ELEVATORS_MODE"
    },
    {
        "SHAP value": -0.0005888192,
        "feature": "LANDAREA_MEDI"
    },
    {
        "SHAP value": -0.0005976825,
        "feature": "CC_AMT_TOTAL_RECEIVABLE_MEAN"
    },
    {
        "SHAP value": -0.0006051306,
        "feature": "NONLIVINGAPARTMENTS_MEDI"
    },
    {
        "SHAP value": -0.0006073738,
        "feature": "CC_AMT_RECIVABLE_MAX"
    },
    {
        "SHAP value": -0.000620327,
        "feature": "PREV_NAME_GOODS_CATEGORY_Computers_MEAN"
    },
    {
        "SHAP value": -0.0006213883,
        "feature": "CC_AMT_BALANCE_MIN"
    },
    {
        "SHAP value": -0.0006221486,
        "feature": "PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN"
    },
    {
        "SHAP value": -0.0006371194,
        "feature": "BURO_AMT_ANNUITY_MEAN"
    },
    {
        "SHAP value": -0.0006676966,
        "feature": "ACTIVE_MONTHS_BALANCE_MAX_MAX"
    },
    {
        "SHAP value": -0.0006736082,
        "feature": "NONLIVINGAREA_AVG"
    },
    {
        "SHAP value": -0.0006776372,
        "feature": "NAME_EDUCATION_TYPE_Lower secondary"
    },
    {
        "SHAP value": -0.0006933208,
        "feature": "CLOSED_DAYS_CREDIT_ENDDATE_MIN"
    },
    {
        "SHAP value": -0.0006957586,
        "feature": "ORGANIZATION_TYPE_Transport: type 3"
    },
    {
        "SHAP value": -0.0007003638,
        "feature": "PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN"
    },
    {
        "SHAP value": -0.0007018102,
        "feature": "PREV_AMT_APPLICATION_MIN"
    },
    {
        "SHAP value": -0.0007028127,
        "feature": "REFUSED_AMT_ANNUITY_MEAN"
    },
    {
        "SHAP value": -0.0007048985,
        "feature": "REFUSED_CNT_PAYMENT_MEAN"
    },
    {
        "SHAP value": -0.0007353578,
        "feature": "CC_AMT_RECIVABLE_MEAN"
    },
    {
        "SHAP value": -0.0007403059,
        "feature": "REFUSED_AMT_ANNUITY_MIN"
    },
    {
        "SHAP value": -0.0007477431,
        "feature": "PREV_AMT_GOODS_PRICE_MIN"
    },
    {
        "SHAP value": -0.0007613996,
        "feature": "CLOSED_DAYS_CREDIT_MIN"
    },
    {
        "SHAP value": -0.0007630699,
        "feature": "POS_NAME_CONTRACT_STATUS_Signed_MEAN"
    },
    {
        "SHAP value": -0.0007813931,
        "feature": "BURO_CREDIT_ACTIVE_Sold_MEAN"
    },
    {
        "SHAP value": -0.0007823493,
        "feature": "PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN"
    },
    {
        "SHAP value": -0.0007856576,
        "feature": "POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN"
    },
    {
        "SHAP value": -0.0007916354,
        "feature": "LANDAREA_AVG"
    },
    {
        "SHAP value": -0.0008380057,
        "feature": "CC_AMT_DRAWINGS_POS_CURRENT_VAR"
    },
    {
        "SHAP value": -0.0008382885,
        "feature": "PREV_NAME_PORTFOLIO_Cards_MEAN"
    },
    {
        "SHAP value": -0.0008425513,
        "feature": "REFUSED_APP_CREDIT_PERC_MAX"
    },
    {
        "SHAP value": -0.0008471167,
        "feature": "BURO_AMT_CREDIT_SUM_OVERDUE_MEAN"
    },
    {
        "SHAP value": -0.0008817304,
        "feature": "PREV_CODE_REJECT_REASON_HC_MEAN"
    },
    {
        "SHAP value": -0.0008834625,
        "feature": "BURO_STATUS_C_MEAN_MEAN"
    },
    {
        "SHAP value": -0.0009179539,
        "feature": "CC_CNT_DRAWINGS_POS_CURRENT_MAX"
    },
    {
        "SHAP value": -0.0009621645,
        "feature": "OCCUPATION_TYPE_nan"
    },
    {
        "SHAP value": -0.0010097449,
        "feature": "PREV_PRODUCT_COMBINATION_Cash_MEAN"
    },
    {
        "SHAP value": -0.0010518822,
        "feature": "POS_MONTHS_BALANCE_MEAN"
    },
    {
        "SHAP value": -0.0010721683,
        "feature": "CC_CNT_DRAWINGS_CURRENT_MAX"
    },
    {
        "SHAP value": -0.0010910662,
        "feature": "PREV_CODE_REJECT_REASON_LIMIT_MEAN"
    },
    {
        "SHAP value": -0.0011125813,
        "feature": "APARTMENTS_AVG"
    },
    {
        "SHAP value": -0.001149959,
        "feature": "APPROVED_AMT_DOWN_PAYMENT_MEAN"
    },
    {
        "SHAP value": -0.0011975559,
        "feature": "PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN"
    },
    {
        "SHAP value": -0.0013970434,
        "feature": "CC_AMT_RECEIVABLE_PRINCIPAL_MEAN"
    },
    {
        "SHAP value": -0.001444755,
        "feature": "REFUSED_AMT_CREDIT_MIN"
    },
    {
        "SHAP value": -0.0014460545,
        "feature": "BURO_MONTHS_BALANCE_MIN_MIN"
    },
    {
        "SHAP value": -0.0014509363,
        "feature": "NAME_FAMILY_STATUS_Single / not married"
    },
    {
        "SHAP value": -0.0014820362,
        "feature": "PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN"
    },
    {
        "SHAP value": -0.0014877523,
        "feature": "REFUSED_AMT_APPLICATION_MAX"
    },
    {
        "SHAP value": -0.0015198554,
        "feature": "REGION_RATING_CLIENT"
    },
    {
        "SHAP value": -0.0015284566,
        "feature": "CC_CNT_DRAWINGS_CURRENT_VAR"
    },
    {
        "SHAP value": -0.001583258,
        "feature": "CLOSED_AMT_CREDIT_SUM_DEBT_MAX"
    },
    {
        "SHAP value": -0.0016604896,
        "feature": "ENTRANCES_AVG"
    },
    {
        "SHAP value": -0.0016889954,
        "feature": "CC_AMT_BALANCE_MEAN"
    },
    {
        "SHAP value": -0.001778758,
        "feature": "OCCUPATION_TYPE_Laborers"
    },
    {
        "SHAP value": -0.0018080794,
        "feature": "ORGANIZATION_TYPE_Construction"
    },
    {
        "SHAP value": -0.0018224173,
        "feature": "INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE"
    },
    {
        "SHAP value": -0.0018255978,
        "feature": "OCCUPATION_TYPE_Drivers"
    },
    {
        "SHAP value": -0.0018277075,
        "feature": "REFUSED_AMT_APPLICATION_MEAN"
    },
    {
        "SHAP value": -0.0018410269,
        "feature": "NAME_HOUSING_TYPE_House / apartment"
    },
    {
        "SHAP value": -0.0018892223,
        "feature": "CC_AMT_DRAWINGS_ATM_CURRENT_MEAN"
    },
    {
        "SHAP value": -0.0018960113,
        "feature": "PREV_CHANNEL_TYPE_Stone_MEAN"
    },
    {
        "SHAP value": -0.0019249039,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN"
    },
    {
        "SHAP value": -0.0019847373,
        "feature": "PREV_HOUR_APPR_PROCESS_START_MIN"
    },
    {
        "SHAP value": -0.0019894591,
        "feature": "APPROVED_AMT_CREDIT_MEAN"
    },
    {
        "SHAP value": -0.0020173867,
        "feature": "CLOSED_AMT_CREDIT_SUM_MEAN"
    },
    {
        "SHAP value": -0.00202987,
        "feature": "ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN"
    },
    {
        "SHAP value": -0.0020411404,
        "feature": "PREV_HOUR_APPR_PROCESS_START_MEAN"
    },
    {
        "SHAP value": -0.002042656,
        "feature": "REFUSED_HOUR_APPR_PROCESS_START_MEAN"
    },
    {
        "SHAP value": -0.0020557891,
        "feature": "APARTMENTS_MEDI"
    },
    {
        "SHAP value": -0.0020705758,
        "feature": "REFUSED_APP_CREDIT_PERC_MIN"
    },
    {
        "SHAP value": -0.0021624304,
        "feature": "CC_CNT_DRAWINGS_CURRENT_MEAN"
    },
    {
        "SHAP value": -0.002186756,
        "feature": "APPROVED_AMT_GOODS_PRICE_MEAN"
    },
    {
        "SHAP value": -0.0022169374,
        "feature": "BURO_MONTHS_BALANCE_SIZE_MEAN"
    },
    {
        "SHAP value": -0.0022781259,
        "feature": "ELEVATORS_AVG"
    },
    {
        "SHAP value": -0.0023045813,
        "feature": "BASEMENTAREA_MODE"
    },
    {
        "SHAP value": -0.0023626398,
        "feature": "APPROVED_CNT_PAYMENT_SUM"
    },
    {
        "SHAP value": -0.0024117971,
        "feature": "ACTIVE_MONTHS_BALANCE_SIZE_SUM"
    },
    {
        "SHAP value": -0.0024745238,
        "feature": "PREV_CODE_REJECT_REASON_XAP_MEAN"
    },
    {
        "SHAP value": -0.0027115351,
        "feature": "PREV_NAME_PRODUCT_TYPE_walk-in_MEAN"
    },
    {
        "SHAP value": -0.0029339176,
        "feature": "CLOSED_DAYS_CREDIT_ENDDATE_MEAN"
    },
    {
        "SHAP value": -0.0029574047,
        "feature": "CLOSED_DAYS_CREDIT_MEAN"
    },
    {
        "SHAP value": -0.0030231148,
        "feature": "REFUSED_HOUR_APPR_PROCESS_START_MIN"
    },
    {
        "SHAP value": -0.0030298571,
        "feature": "INCOME_PER_PERSON"
    },
    {
        "SHAP value": -0.0030451162,
        "feature": "ACTIVE_MONTHS_BALANCE_MIN_MIN"
    },
    {
        "SHAP value": -0.003086144,
        "feature": "DAYS_REGISTRATION"
    },
    {
        "SHAP value": -0.0031391292,
        "feature": "CC_CNT_DRAWINGS_ATM_CURRENT_VAR"
    },
    {
        "SHAP value": -0.0032894476,
        "feature": "INSTAL_PAYMENT_DIFF_SUM"
    },
    {
        "SHAP value": -0.0034058925,
        "feature": "APARTMENTS_MODE"
    },
    {
        "SHAP value": -0.0035353526,
        "feature": "ACTIVE_AMT_ANNUITY_MAX"
    },
    {
        "SHAP value": -0.0035711088,
        "feature": "DEF_60_CNT_SOCIAL_CIRCLE"
    },
    {
        "SHAP value": -0.0037605681,
        "feature": "APPROVED_AMT_APPLICATION_MIN"
    },
    {
        "SHAP value": -0.0037855266,
        "feature": "PREV_NAME_GOODS_CATEGORY_XNA_MEAN"
    },
    {
        "SHAP value": -0.0037899978,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN"
    },
    {
        "SHAP value": -0.0038973878,
        "feature": "PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN"
    },
    {
        "SHAP value": -0.00391708,
        "feature": "CLOSED_MONTHS_BALANCE_SIZE_MEAN"
    },
    {
        "SHAP value": -0.0040393396,
        "feature": "PREV_AMT_APPLICATION_MEAN"
    },
    {
        "SHAP value": -0.004191327,
        "feature": "APPROVED_DAYS_DECISION_MAX"
    },
    {
        "SHAP value": -0.0042059693,
        "feature": "ACTIVE_AMT_CREDIT_SUM_DEBT_SUM"
    },
    {
        "SHAP value": -0.0042776693,
        "feature": "PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN"
    },
    {
        "SHAP value": -0.0043811057,
        "feature": "PREV_NAME_YIELD_GROUP_XNA_MEAN"
    },
    {
        "SHAP value": -0.0043970039,
        "feature": "BURO_CREDIT_TYPE_Credit card_MEAN"
    },
    {
        "SHAP value": -0.0045194059,
        "feature": "INSTAL_PAYMENT_DIFF_VAR"
    },
    {
        "SHAP value": -0.0045276696,
        "feature": "REFUSED_DAYS_DECISION_MEAN"
    },
    {
        "SHAP value": -0.0047856718,
        "feature": "BURO_AMT_CREDIT_SUM_MEAN"
    },
    {
        "SHAP value": -0.0048636181,
        "feature": "BURO_AMT_CREDIT_SUM_LIMIT_SUM"
    },
    {
        "SHAP value": -0.005009064,
        "feature": "ACTIVE_AMT_CREDIT_SUM_SUM"
    },
    {
        "SHAP value": -0.0052252769,
        "feature": "PREV_CNT_PAYMENT_SUM"
    },
    {
        "SHAP value": -0.0053793639,
        "feature": "ORGANIZATION_TYPE_Business Entity Type 3"
    },
    {
        "SHAP value": -0.0057276137,
        "feature": "BURO_DAYS_CREDIT_UPDATE_MEAN"
    },
    {
        "SHAP value": -0.0058566583,
        "feature": "PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN"
    },
    {
        "SHAP value": -0.0061908707,
        "feature": "CLOSED_MONTHS_BALANCE_MIN_MIN"
    },
    {
        "SHAP value": -0.0062341218,
        "feature": "CLOSED_AMT_CREDIT_SUM_MAX"
    },
    {
        "SHAP value": -0.0062386501,
        "feature": "APPROVED_APP_CREDIT_PERC_MIN"
    },
    {
        "SHAP value": -0.0062679826,
        "feature": "PREV_APP_CREDIT_PERC_VAR"
    },
    {
        "SHAP value": -0.0064104706,
        "feature": "PREV_PRODUCT_COMBINATION_POS household with interest_MEAN"
    },
    {
        "SHAP value": -0.0064106215,
        "feature": "PREV_AMT_CREDIT_MEAN"
    },
    {
        "SHAP value": -0.0067890333,
        "feature": "PREV_NAME_YIELD_GROUP_middle_MEAN"
    },
    {
        "SHAP value": -0.0069052034,
        "feature": "INSTAL_DBD_MEAN"
    },
    {
        "SHAP value": -0.0069182828,
        "feature": "BURO_STATUS_1_MEAN_MEAN"
    },
    {
        "SHAP value": -0.0072615473,
        "feature": "PREV_NAME_CONTRACT_STATUS_Refused_MEAN"
    },
    {
        "SHAP value": -0.0073310051,
        "feature": "CLOSED_DAYS_CREDIT_ENDDATE_MAX"
    },
    {
        "SHAP value": -0.0073834174,
        "feature": "INSTAL_PAYMENT_PERC_MEAN"
    },
    {
        "SHAP value": -0.0076356419,
        "feature": "AMT_INCOME_TOTAL"
    },
    {
        "SHAP value": -0.0078922279,
        "feature": "ORGANIZATION_TYPE_Self-employed"
    },
    {
        "SHAP value": -0.0079197377,
        "feature": "BURO_CREDIT_TYPE_Microloan_MEAN"
    },
    {
        "SHAP value": -0.0079371179,
        "feature": "CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN"
    },
    {
        "SHAP value": -0.0079453938,
        "feature": "REG_CITY_NOT_LIVE_CITY"
    },
    {
        "SHAP value": -0.008038578,
        "feature": "INSTAL_AMT_PAYMENT_MAX"
    },
    {
        "SHAP value": -0.0081055961,
        "feature": "ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN"
    },
    {
        "SHAP value": -0.0081711192,
        "feature": "PREV_NAME_PAYMENT_TYPE_XNA_MEAN"
    },
    {
        "SHAP value": -0.0083307432,
        "feature": "INSTAL_PAYMENT_DIFF_MEAN"
    },
    {
        "SHAP value": -0.0085097812,
        "feature": "CC_CNT_DRAWINGS_ATM_CURRENT_MEAN"
    },
    {
        "SHAP value": -0.0085379125,
        "feature": "PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN"
    },
    {
        "SHAP value": -0.0086900057,
        "feature": "REFUSED_DAYS_DECISION_MAX"
    },
    {
        "SHAP value": -0.0089309754,
        "feature": "WALLSMATERIAL_MODE_Stone, brick"
    },
    {
        "SHAP value": -0.009321839,
        "feature": "INSTAL_AMT_INSTALMENT_MAX"
    },
    {
        "SHAP value": -0.0098774821,
        "feature": "PREV_APP_CREDIT_PERC_MIN"
    },
    {
        "SHAP value": -0.009909444,
        "feature": "INSTAL_DAYS_ENTRY_PAYMENT_MEAN"
    },
    {
        "SHAP value": -0.0108792786,
        "feature": "PREV_AMT_APPLICATION_MAX"
    },
    {
        "SHAP value": -0.0110440334,
        "feature": "ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN"
    },
    {
        "SHAP value": -0.011250454,
        "feature": "BURO_AMT_CREDIT_SUM_DEBT_SUM"
    },
    {
        "SHAP value": -0.0112796572,
        "feature": "PREV_NAME_TYPE_SUITE_nan_MEAN"
    },
    {
        "SHAP value": -0.0121067635,
        "feature": "FLAG_WORK_PHONE"
    },
    {
        "SHAP value": -0.0126155284,
        "feature": "CLOSED_DAYS_CREDIT_VAR"
    },
    {
        "SHAP value": -0.0126356253,
        "feature": "DEF_30_CNT_SOCIAL_CIRCLE"
    },
    {
        "SHAP value": -0.0126909707,
        "feature": "POS_SK_DPD_MEAN"
    },
    {
        "SHAP value": -0.013132156,
        "feature": "PREV_NAME_CONTRACT_STATUS_Approved_MEAN"
    },
    {
        "SHAP value": -0.01364918,
        "feature": "BURO_AMT_CREDIT_SUM_SUM"
    },
    {
        "SHAP value": -0.0136609185,
        "feature": "INSTAL_PAYMENT_DIFF_MAX"
    },
    {
        "SHAP value": -0.013863671,
        "feature": "PREV_AMT_ANNUITY_MAX"
    },
    {
        "SHAP value": -0.0140079153,
        "feature": "BURO_STATUS_0_MEAN_MEAN"
    },
    {
        "SHAP value": -0.0141361582,
        "feature": "APPROVED_CNT_PAYMENT_MEAN"
    },
    {
        "SHAP value": -0.0155535622,
        "feature": "DAYS_BIRTH"
    },
    {
        "SHAP value": -0.0162727874,
        "feature": "PREV_AMT_CREDIT_MAX"
    },
    {
        "SHAP value": -0.0165246608,
        "feature": "ACTIVE_DAYS_CREDIT_UPDATE_MEAN"
    },
    {
        "SHAP value": -0.0165607726,
        "feature": "CLOSED_AMT_ANNUITY_MAX"
    },
    {
        "SHAP value": -0.0169166146,
        "feature": "PREV_AMT_GOODS_PRICE_MEAN"
    },
    {
        "SHAP value": -0.0185958052,
        "feature": "POS_NAME_CONTRACT_STATUS_Completed_MEAN"
    },
    {
        "SHAP value": -0.0210385872,
        "feature": "DAYS_LAST_PHONE_CHANGE"
    },
    {
        "SHAP value": -0.0226360178,
        "feature": "CLOSED_AMT_CREDIT_SUM_SUM"
    },
    {
        "SHAP value": -0.0245636565,
        "feature": "NAME_EDUCATION_TYPE_Secondary / secondary special"
    },
    {
        "SHAP value": -0.0257041841,
        "feature": "PREV_APP_CREDIT_PERC_MEAN"
    },
    {
        "SHAP value": -0.0373150673,
        "feature": "BURO_DAYS_CREDIT_ENDDATE_MAX"
    },
    {
        "SHAP value": -0.0385204478,
        "feature": "CLOSED_DAYS_CREDIT_UPDATE_MEAN"
    },
    {
        "SHAP value": -0.0389339381,
        "feature": "ANNUITY_INCOME_PERC"
    },
    {
        "SHAP value": -0.039125673,
        "feature": "PREV_NAME_CLIENT_TYPE_New_MEAN"
    },
    {
        "SHAP value": -0.0397815925,
        "feature": "HOUR_APPR_PROCESS_START"
    },
    {
        "SHAP value": -0.0429617899,
        "feature": "PAYMENT_RATE"
    },
    {
        "SHAP value": -0.0465743047,
        "feature": "PREV_CNT_PAYMENT_MEAN"
    },
    {
        "SHAP value": -0.0483305696,
        "feature": "NAME_FAMILY_STATUS_Married"
    },
    {
        "SHAP value": -0.049754003,
        "feature": "ORGANIZATION_TYPE_Kindergarten"
    },
    {
        "SHAP value": -0.0497789705,
        "feature": "AMT_ANNUITY"
    },
    {
        "SHAP value": -0.0741976884,
        "feature": "PREV_NAME_CLIENT_TYPE_Refreshed_MEAN"
    },
    {
        "SHAP value": -0.1177052856,
        "feature": "NAME_EDUCATION_TYPE_Higher education"
    },
    {
        "SHAP value": -0.4424087757,
        "feature": "EXT_SOURCE_1"
    },
    {
        "SHAP value": -0.824262692,
        "feature": "EXT_SOURCE_2"
    }
]

# %%
df = pd.DataFrame(json_shap)

# %%
df.sort_values(by="SHAP value", ascending=False, inplace=True)

# %%
df
# Out:
#      SHAP value                               feature
# 0      0.728414                          EXT_SOURCE_3
# 1      0.146712                           CODE_GENDER
# 2      0.125585                ACTIVE_DAYS_CREDIT_MAX
# 3      0.088843                       INSTAL_DPD_MEAN
# 4      0.082880                           OWN_CAR_AGE
# ..          ...                                   ...
# 772   -0.049779                           AMT_ANNUITY
# 773   -0.074198  PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
# 774   -0.117705  NAME_EDUCATION_TYPE_Higher education
# 775   -0.442409                          EXT_SOURCE_1
# 776   -0.824263                          EXT_SOURCE_2
#
# [777 rows x 2 columns]
